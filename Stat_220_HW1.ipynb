# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drbob-richardson/stat220/blob/main/Assignments/Stat_220_HW1.ipynb)

# %% [markdown]
# **Problem 1**. Give an example of a variable that is (a) categorical; (b) quantitative; (c) discrete; (d) continuous.

# %% [markdown]
# (a) Favorite Food
# (b) 5K time
# (c) M&Ms in a bag
# (d) Tooth Length

# %% [markdown]
# **Problem 2**. Analyze the Carbon_West data file using the following code.

# %%
import pandas as pd
import matplotlib.pyplot as plt
carbon_west = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Carbon_West.dat")

# %% [markdown]
# Part a. Construct a histogram of CO2 emissions.

# %%
plt.hist(carbon_west['CO2'])
plt.xlabel('CO2 Emissions')
plt.ylabel('Frequency')
plt.title('Histogram of CO2 Emissions')
plt.show()

# %% [markdown]
# Part b. Find the mean, median, and standard deviation.

# %%
print("Mean:", carbon_west['CO2'].mean())
print("Median:", carbon_west['CO2'].median())
print("Standard Deviation:", carbon_west['CO2'].std())

# %% [markdown]
# **Problem 3**. Read in the murder data set using the following code. The variable murder is the murder rate (per 100,000 population) for each state in the U.S. in 2017 according to the FBI Uniform Crime Reports. At first, do not use the observation for D.C. (DC).

# %%
murders = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Murder.dat")

# %% [markdown]
# Part a. Find the mean and standard deviation for murders without D.C.

# %%
murders_no_dc = murders[murders['state'] != 'DC']

mean_murders = murders_no_dc['murder'].mean()
std_murders = murders_no_dc['murder'].std()

print("Mean:", mean_murders)
print("Standard Deviation:", std_murders)

# %% [markdown]
# Part b. Find the five-number  summary without D.C.

# %%
min_murders = murders_no_dc['murder'].min()
q1_murders = murders_no_dc['murder'].quantile(0.25)
median_murders = murders_no_dc['murder'].median()
q3_murders = murders_no_dc['murder'].quantile(0.75)
max_murders = murders_no_dc['murder'].max()

print("Minimum:", min_murders)
print("Q1:", q1_murders)
print("Median:", median_murders)
print("Q3:", q3_murders)
print("Maximum:", max_murders)

# %% [markdown]
# Part c. Now include the observation for D.C. and recalculate the mean, median, and five-number summary. What is affected more by this outlier: The mean or the median? The range or the inter-quartile range?

# %%
mean_murders_with_dc = murders['murder'].mean()
median_murders_with_dc = murders['murder'].median()
min_murders_with_dc = murders['murder'].min()
q1_murders_with_dc = murders['murder'].quantile(0.25)
q3_murders_with_dc = murders['murder'].quantile(0.75)
max_murders_with_dc = murders['murder'].max()

print("Mean with D.C.:", mean_murders_with_dc)
print("Median with D.C.:", median_murders_with_dc)
print("Minimum with D.C.:", min_murders_with_dc)
print("Q1 with D.C.:", q1_murders_with_dc)
print("Median with D.C.:", median_murders_with_dc)
print("Q3 with D.C.:", q3_murders_with_dc)
print("Maximum with D.C.:", max_murders_with_dc)

print("\nThe mean is affected more by the outlier than the median.")
print("The range is affected more by the outlier than the inter-quartile range.")

# %% [markdown]
# **Problem 4**. Read in the Houses data file using the following code.  The variables include price (thousands of dollars), size (square feet), tax bill (dollars), number of bathrooms, number of bedrooms, and whether the house is new (1 = yes, 0 = no) for 100 home sales in Gainesville, Florida. Let
# y = selling price and x = size of home.

# %%
houses = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Houses.dat")

# %% [markdown]
# Part a. Construct a scatterplot between square feet and price of a home.

# %%
plt.scatter(houses['size'], houses['price'])
plt.xlabel('Size (square feet)')
plt.ylabel('Price (thousands of dollars)')
plt.title('Scatterplot of Size vs. Price')
plt.show()

# %% [markdown]
# Part b. Find the correlation between the two variables.

# %%
correlation = houses['size'].corr(houses['price'])
print("Correlation:", correlation)

# %% [markdown]
# Part c. Find and plot the regression line on top of the scatterplot.

# %%
import statsmodels.formula.api as smf

model = smf.ols('price ~ size', data=houses).fit()

slope = model.params['size']
intercept = model.params['Intercept']

plt.scatter(houses['size'], houses['price'])
plt.xlabel('Size (square feet)')
plt.ylabel('Price (thousands of dollars)')
plt.title('Scatterplot of Size vs. Price with Regression Line')

x_values = [houses['size'].min(), houses['size'].max()]
y_values = [intercept + slope * x for x in x_values]
plt.plot(x_values, y_values, color='red')

plt.show()

# %% [markdown]
# Part d. Create a side by side boxplot of price comparing homes that are new and homes that are not new.

# %%
houses_new = houses[houses['new'] == 1]
houses_old = houses[houses['new'] == 0]

plt.boxplot([houses_new['price'], houses_old['price']], labels=['New', 'Old'])
plt.xlabel('New vs. Old Homes')
plt.ylabel('Price (thousands of dollars)')
plt.title('Boxplot of Price by New vs. Old Homes')
plt.show()

# %% [markdown]
# Part e. What is the relationship between size and price.  Justify your answer using the plots created. Do the same for the relationship between price and whether or not a house is new, again using the plot to justify your answer.

# %% [markdown]
# The relationship between price and size is a positive correlation. The larger the size, the higher the price, on average (seen from the regression line having a positive slope) and the relationship between a newer home and price is also positive. the newer the home, the more expensive, on average. (seen from the box plot being higher in the new vs old plot)

# %% [markdown]
# **Problem 1.22**. Using the Happy data file read in by the following code. Construct the contingency table relating marital status and happiness.

# %%
happy = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Happy.dat")

# %%
contingency_table = pd.crosstab(happy['marital'], happy['happiness'])
print(contingency_table)
